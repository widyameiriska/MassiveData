# %% [markdown]
# # Ethereum Dataset

# %% [markdown]
# by: Widya Meiriska

# %% [markdown]
# ### 1. Read Dataset¶

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/bitcoin/ethereum_dataset.csv',parse_dates = ['Date(UTC)'])

# %%
df.tail()
# Out:
#      Date(UTC)  UnixTimeStamp  eth_etherprice  eth_tx  eth_address  \
# 764 2017-09-01     1504224000             0.0  390997      6837885
# 765 2017-09-02     1504310400             0.0  331797      6892287
# 766 2017-09-03     1504396800             0.0  302525      6941689
# 767 2017-09-04     1504483200             0.0  442592      7004719
# 768 2017-09-05     1504569600             0.0  444413      7067860
#
#        eth_supply  eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# 764  9.437595e+07            0.0    92728.0146        2233.569        3521
# 765  9.439480e+07            0.0    93720.5494        2231.260        3541
# 766  9.441344e+07            0.0    95055.9858        2250.289        3539
# 767  9.443236e+07            0.0    93647.0268        2243.963        3527
# 768  9.445146e+07            0.0    93751.8522        2231.020        3558
#
#      eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  eth_gaslimit  \
# ...

# %% [markdown]
# ### 2. Data Investigation

# %%
df.columns
# Out:
# Index(['Date(UTC)', 'UnixTimeStamp', 'eth_etherprice', 'eth_tx', 'eth_address',
#        'eth_supply', 'eth_marketcap', 'eth_hashrate', 'eth_difficulty',
#        'eth_blocks', 'eth_uncles', 'eth_blocksize', 'eth_blocktime',
#        'eth_gasprice', 'eth_gaslimit', 'eth_gasused', 'eth_ethersupply',
#        'eth_chaindatasize', 'eth_ens_register'],
#       dtype='object')

# %%
df.count()
# Out:
# Date(UTC)            769
# UnixTimeStamp        769
# eth_etherprice       769
# eth_tx               769
# eth_address          769
# eth_supply           769
# eth_marketcap        769
# eth_hashrate         769
# eth_difficulty       769
# eth_blocks           769
# eth_uncles           769
# eth_blocksize        769
# eth_blocktime        769
# eth_gasprice         769
# eth_gaslimit         769
# eth_gasused          769
# eth_ethersupply      769
# eth_chaindatasize      0
# eth_ens_register     125
# dtype: int64

# %%
df.dtypes
# Out:
# Date(UTC)            datetime64[ns]
# UnixTimeStamp                 int64
# eth_etherprice              float64
# eth_tx                        int64
# eth_address                   int64
# eth_supply                  float64
# eth_marketcap               float64
# eth_hashrate                float64
# eth_difficulty              float64
# eth_blocks                    int64
# eth_uncles                    int64
# eth_blocksize                 int64
# eth_blocktime               float64
# eth_gasprice                  int64
# eth_gaslimit                  int64
# eth_gasused                   int64
# eth_ethersupply             float64
# eth_chaindatasize           float64
# eth_ens_register            float64
# dtype: object

# %%
# Set Date as it's index
df.set_index('Date(UTC)', inplace = True )

# %%
#drop chaindatasize column
df.drop(['eth_chaindatasize'], inplace=True, axis=1)
df.head()
# Out:
#             UnixTimeStamp  eth_etherprice  eth_tx  eth_address    eth_supply  \
# Date(UTC)
# 2015-07-30     1438214400             0.0    8893         9205  7.204931e+07
# 2015-07-31     1438300800             0.0       0         9361  7.208550e+07
# 2015-08-01     1438387200             0.0       0         9476  7.211320e+07
# 2015-08-02     1438473600             0.0       0         9563  7.214143e+07
# 2015-08-03     1438560000             0.0       0         9639  7.216940e+07
#
#             eth_marketcap  eth_hashrate  eth_difficulty  eth_blocks  \
# Date(UTC)
# 2015-07-30            0.0       23.7569           0.121        6912
# 2015-07-31            0.0       48.1584           0.603        6863
# 2015-08-01            0.0       55.2709           0.887        5293
# 2015-08-02            0.0       64.1779           1.020        5358
# 2015-08-03            0.0       69.8559           1.126        5280
#
#             eth_uncles  eth_blocksize  eth_blocktime  eth_gasprice  \
# ...

# %%
df.describe()
# Out:
#        UnixTimeStamp  eth_etherprice         eth_tx   eth_address  \
# count   7.690000e+02      769.000000     769.000000  7.690000e+02
# mean    1.471392e+09       46.920806   70564.308192  1.050655e+06
# std     1.919250e+07       90.378356   89424.024060  1.521229e+06
# min     1.438214e+09        0.000000       0.000000  9.205000e+03
# 25%     1.454803e+09        2.520000   17549.000000  5.892500e+04
# 50%     1.471392e+09       10.970000   42346.000000  5.394280e+05
# 75%     1.487981e+09       14.990000   58756.000000  1.081093e+06
# max     1.504570e+09      394.660000  444413.000000  7.067860e+06
#
#          eth_supply  eth_marketcap  eth_hashrate  eth_difficulty   eth_blocks  \
# count  7.690000e+02     769.000000    769.000000      769.000000   769.000000
# mean   8.320820e+07    4301.621649  13247.782131      233.619406  5517.196359
# std    6.753548e+06    8451.186405  22419.039496      455.312190   627.739112
# ...

# %% [markdown]
# ### 3. Data Visualization

# %%
# Visualization the average of Open based on time (Week)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(25, 25))

plt.subplot(3,3,1)
plt.ylabel('eth_etherprice')
df.eth_etherprice.plot()

plt.subplot(3,3,2)
plt.ylabel('eth_supply')
df.eth_supply.plot()

plt.subplot(3,3,3)
plt.ylabel('eth_marketcap')
df.eth_marketcap.plot()

plt.subplot(3,3,4)
plt.ylabel('eth_ens_register')
df.eth_ens_register.plot()

plt.subplot(3,3,5)
plt.ylabel('eth_hashrate')
df.eth_hashrate.plot()

plt.subplot(3,3,6)
plt.ylabel('eth_blocksize')
df['eth_blocksize'].plot()
