# %% [markdown]
# # Iota Price

# %% [markdown]
# by: Widya Meiriska

# %% [markdown]
# ### 1. Read Dataset

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/bitcoin/iota_price.csv', parse_dates = ['Date'])

# %%
df.tail()
# Out:
#          Date      Open      High       Low     Close      Volume  \
# 80 2017-06-17  0.426762  0.444205  0.414139  0.419906   3,100,660
# 81 2017-06-16  0.353285  0.448249  0.309852  0.410757   6,920,690
# 82 2017-06-15  0.528284  0.543165  0.300365  0.363661  10,300,400
# 83 2017-06-14  0.592347  0.606196  0.495745  0.528916  14,194,900
# 84 2017-06-13  0.638503  0.652862  0.533910  0.590255  25,425,600
#
#        Market Cap
# 80  1,186,200,000
# 81    981,966,000
# 82  1,468,380,000
# 83  1,646,450,000
# 84  1,774,740,000

# %% [markdown]
# ### 2. Data Investigation

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
df.count()
# Out:
# Date          85
# Open          85
# High          85
# Low           85
# Close         85
# Volume        85
# Market Cap    85
# dtype: int64

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                object
# Market Cap            object
# dtype: object

# %%
df.describe()
# Out:
#             Open       High        Low      Close
# count  85.000000  85.000000  85.000000  85.000000
# mean    0.501695   0.537700   0.455827   0.502194
# std     0.254753   0.267625   0.232656   0.256240
# min     0.157961   0.176099   0.147933   0.158688
# 25%     0.286164   0.304476   0.262736   0.284565
# 50%     0.413371   0.437340   0.388231   0.410757
# 75%     0.722169   0.775863   0.658006   0.721535
# max     1.040000   1.100000   0.998241   1.050000

# %% [markdown]
# #### There is no missing data here and there are several data which have different format. Some of the data do not use number format

# %%
df['Volume'] = df['Volume'].apply(lambda x: float(str(x).replace(',',''))) 
df['Market Cap'] = df['Market Cap'].apply(lambda x: float(str(x).replace(',','')))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 7 columns):
# Date          85 non-null datetime64[ns]
# Open          85 non-null float64
# High          85 non-null float64
# Low           85 non-null float64
# Close         85 non-null float64
# Volume        85 non-null float64
# Market Cap    85 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 4.7 KB

# %%
df.tail()
# Out:
#          Date      Open      High       Low     Close      Volume  \
# 80 2017-06-17  0.426762  0.444205  0.414139  0.419906   3100660.0
# 81 2017-06-16  0.353285  0.448249  0.309852  0.410757   6920690.0
# 82 2017-06-15  0.528284  0.543165  0.300365  0.363661  10300400.0
# 83 2017-06-14  0.592347  0.606196  0.495745  0.528916  14194900.0
# 84 2017-06-13  0.638503  0.652862  0.533910  0.590255  25425600.0
#
#       Market Cap
# 80  1.186200e+09
# 81  9.819660e+08
# 82  1.468380e+09
# 83  1.646450e+09
# 84  1.774740e+09

# %%
missingdf = pd.DataFrame(df.isna().sum()).rename(columns = {0: 'total'})
missingdf['percent'] = missingdf['total'] / len(df)
missingdf
# Out:
#             total  percent
# Date            0      0.0
# Open            0      0.0
# High            0      0.0
# Low             0      0.0
# Close           0      0.0
# Volume          0      0.0
# Market Cap      0      0.0

# %% [markdown]
# #### Now the data is clean, no null value and has same format¶

# %% [markdown]
# ### 3. Data Visualization

# %%
# Set Date as it's index
df.set_index('Date', inplace = True )

# %%
# Visualization the average of Open based on time (Week)
# %matplotlib inline
plt.figure(figsize=(25, 25))

plt.subplot(3,3,1)
plt.ylabel('Open')
df.Open.plot()
plt.title('Date vs Open')

plt.subplot(3,3,2)
plt.ylabel('Low')
df.Low.plot()
plt.title('Date vs Low')

plt.subplot(3,3,3)
plt.ylabel('High')
df.High.plot()
plt.title('Date vs High')

plt.subplot(3,3,4)
plt.ylabel('Close')
df.Close.plot()
plt.title('Date vs Close')

plt.subplot(3,3,5)
plt.ylabel('Volume')
df.Volume.plot()
plt.title('Date vs Volume')

plt.subplot(3,3,6)
plt.ylabel('Market Cap')
df['Market Cap'].plot()
plt.title('Date vs Market Cap')
# Out:
# Text(0.5,1,'Date vs Market Cap')
